# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

bd1_data_path = "Resources/Realtor_1BD.csv"
bd2_data_path = "Resources/Realtor_2BD.csv"
bd3_data_path = "Resources/Realtor_3BD.csv"
bd4_data_path = "Resources/Realtor_4BD.csv"
bd5_data_path = "Resources/Realtor_5BD.csv"

austin_bnb_path = "Resources/aus_listings.csv"
boston_bnb_path = "Resources/bos_listings.csv"
chicago_bnb_path = "Resources/chi_listings.csv"
sandiego_bnb_path = "Resources/sd_listings.csv"
seattle_bnb_path = "Resources/sea_listings.csv"

bd1_df = pd.read_csv(bd1_data_path)
bd2_df = pd.read_csv(bd2_data_path)
bd3_df = pd.read_csv(bd3_data_path)
bd4_df = pd.read_csv(bd4_data_path)
bd5_df = pd.read_csv(bd5_data_path)

aus_bnb_df = pd.read_csv(austin_bnb_path)
bos_bnb_df = pd.read_csv(boston_bnb_path)
chi_bnb_df = pd.read_csv(chicago_bnb_path)
sd_bnb_df = pd.read_csv(sandiego_bnb_path)
sea_bnb_df = pd.read_csv(seattle_bnb_path)

aus_bnb_df.head()
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      id                        listing_url       scrape_id last_scraped  \
# 0  2265  https://www.airbnb.com/rooms/2265  20181112235459   2018-11-13
# 1  5245  https://www.airbnb.com/rooms/5245  20181112235459   2018-11-13
# 2  5456  https://www.airbnb.com/rooms/5456  20181112235459   2018-11-13
# 3  5769  https://www.airbnb.com/rooms/5769  20181112235459   2018-11-13
# 4  6413  https://www.airbnb.com/rooms/6413  20181112235459   2018-11-13
#
#                                         name  \
# 0            Zen-East in the Heart of Austin
# 1        Green, Colorful, Clean &  Cozy home
# 2  Walk to 6th, Rainey St and Convention Ctr
# 3                             NW Austin Room
# 4              Gem of a Studio near Downtown
#
#                                              summary  \
# 0  Zen East is situated in a vibrant & diverse mu...
# 1                                                NaN
# 2  Fabulous location for walking to Convention Ce...
# 3                                                NaN
# 4  Great studio apartment, perfect for couples or...
#
#                                                space  \
# 0  This colorful and clean 1923 house was complet...
# 1  Situated in a vibrant & diverse multicultural ...
# 2  Cute Private Studio apartment located in Willo...
# 3  Looking for a comfortable inexpensive room to ...
# 4  (License #114332) Large, contemporary studio a...
#
#                                          description experiences_offered  \
# 0  Zen East is situated in a vibrant & diverse mu...                none
# 1  Situated in a vibrant & diverse multicultural ...                none
# 2  Fabulous location for walking to Convention Ce...                none
# 3  Looking for a comfortable inexpensive room to ...                none
# 4  Great studio apartment, perfect for couples or...                none
#
#                                neighborhood_overview        ...          \
# 0                                                NaN        ...
# 1                                                NaN        ...
# 2  My neighborhood is ideally located if you want...        ...
# 3  Quiet neighborhood with lots of trees and good...        ...
# 4  Travis Heights is one of the oldest neighborho...        ...
#
#   requires_license      license jurisdiction_names instant_bookable  \
# 0                f          NaN    {"Texas State"}                f
# 1                f          NaN    {"Texas State"}                f
# 2                f          NaN    {"Texas State"}                f
# 3                f          NaN    {"Texas State"}                f
# 4                f  32041657928    {"Texas State"}                t
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f                     moderate
# 4                        f  strict_14_with_grace_period
#
#    require_guest_profile_picture require_guest_phone_verification  \
# 0                              f                                f
# 1                              f                                f
# 2                              f                                t
# 3                              t                                t
# 4                              f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               3               0.20
# 1                               3               0.08
# 2                               1               3.91
# 3                               1               2.27
# 4                               1               0.73
#
# [5 rows x 96 columns]

# %%
bd1_df.head()
# Out:
#     Month  CBSACode                             CBSATitle Country  \
# 0  201811   36540.0           Omaha-Council Bluffs, NE-IA     USA
# 1  201811   10140.0                          Aberdeen, WA     USA
# 2  201811   26420.0  Houston-The Woodlands-Sugar Land, TX     USA
# 3  201811   34740.0                          Muskegon, MI     USA
# 4  201811   23860.0                        Georgetown, SC     USA
#
#                     PropertyType NoOfBdrs  MedianListingPrice   \
# 0  Condo/Townhome/Row Home/Co-Op   bdrs_1             193725.0
# 1  Condo/Townhome/Row Home/Co-Op   bdrs_1              81550.0
# 2  Condo/Townhome/Row Home/Co-Op   bdrs_1             146675.0
# 3  Condo/Townhome/Row Home/Co-Op   bdrs_1             129950.0
# 4  Condo/Townhome/Row Home/Co-Op   bdrs_1             153784.5
#
#    MedianListingPrice M/M  MedianListingPrice Y/Y  MedianListingSqft   \
# 0                 -0.1651                  0.6590               930.0
# 1                  0.0316                 -0.1638               612.0
# 2                 -0.0215                  0.0481               793.0
# 3                 -0.0371                  0.0048               791.0
# 4                  0.0605                 -0.1088               501.0
#
#         ...         TotalListingCount Y/Y  PendingRatio  PendingRatio M/M  \
# 0       ...                       -0.0328        0.0000            0.0000
# 1       ...                       -0.0222        0.0732            0.0219
# 2       ...                        0.0338        0.2307           -0.0041
# 3       ...                        3.5000        0.0000            0.0000
# 4       ...                       -0.3429        0.0000            0.0000
#
#    PendingRatio Y/Y  Views M/M  Views Y/Y  ViewsPerProperty M/M  \
# 0           -0.4524    -0.3377    -0.0208               -0.2385
# 1           -0.0244    -0.2160     0.1861               -0.2353
# 2           -0.0729    -0.0900     0.0412               -0.0769
# 3            0.0000    -0.3629     2.9752               -0.4157
# 4            0.0000     0.6983    -0.3091                0.5000
#
#    ViewsPerProperty Y/Y  QualityFlagPending  QualityFlagSqft
# 0               -0.3083                 1.0              0.0
# 1                0.2264                 0.0              0.0
# 2               -0.0588                 0.0              0.0
# 3               -0.1333                 0.0              0.0
# 4                0.1250                 0.0              0.0
#
# [5 rows x 50 columns]

# %%
bd1_df = bd1_df[bd1_df["CBSATitle"].str.contains("Boston|Austin|San Diego|Chicago|Seattle") == True]
bd1_df = bd1_df[bd1_df["CBSATitle"].str.contains("MN") == False]
bd1_df = bd1_df[bd1_df["PropertyType"] == "Total"]
bd1_df = bd1_df[["CBSATitle","PropertyType","MedianListingPrice "]]

bd2_df = bd2_df[bd2_df["CBSATitle"].str.contains("Boston|Austin|San Diego|Chicago|Seattle") == True]
bd2_df = bd2_df[bd2_df["CBSATitle"].str.contains("MN") == False]
bd2_df = bd2_df[bd2_df["PropertyType"] == "Total"]
bd2_df = bd2_df[["CBSATitle","PropertyType","MedianListingPrice "]]

bd3_df = bd3_df[bd3_df["CBSATitle"].str.contains("Boston|Austin|San Diego|Chicago|Seattle") == True]
bd3_df = bd3_df[bd3_df["CBSATitle"].str.contains("MN") == False]
bd3_df = bd3_df[bd3_df["PropertyType"] == "Total"]
bd3_df = bd3_df[["CBSATitle","PropertyType","MedianListingPrice "]]

bd4_df = bd4_df[bd4_df["CBSATitle"].str.contains("Boston|Austin|San Diego|Chicago|Seattle") == True]
bd4_df = bd4_df[bd4_df["CBSATitle"].str.contains("MN") == False]
bd4_df = bd4_df[bd4_df["PropertyType"] == "Total"]
bd4_df = bd4_df[["CBSATitle","PropertyType","MedianListingPrice "]]

bd5_df = bd5_df[bd5_df["CBSATitle"].str.contains("Boston|Austin|San Diego|Chicago|Seattle") == True]
bd5_df = bd5_df[bd5_df["CBSATitle"].str.contains("MN") == False]
bd5_df = bd5_df[bd5_df["PropertyType"] == "Total"]
bd5_df = bd5_df[["CBSATitle","PropertyType","MedianListingPrice "]]

bd1_df.head()
# Out:
#                                CBSATitle PropertyType  MedianListingPrice
# 1361         Seattle-Tacoma-Bellevue, WA        Total             405787.5
# 1447  Chicago-Naperville-Elgin, IL-IN-WI        Total             179550.0
# 1646      Boston-Cambridge-Newton, MA-NH        Total             357450.0
# 1744               Austin-Round Rock, TX        Total             305050.0
# 1791              San Diego-Carlsbad, CA        Total             358675.0

# %%
aus_bnb_df = aus_bnb_df[["latitude","longitude","room_type","bedrooms","price","minimum_nights",
                         "availability_365","number_of_reviews","reviews_per_month"]]
aus_bnb_df = aus_bnb_df.dropna()
aus_bnb_df = aus_bnb_df[aus_bnb_df["room_type"] == "Entire home/apt"]

bos_bnb_df = bos_bnb_df[["latitude","longitude","room_type","bedrooms","price","minimum_nights",
                         "availability_365","number_of_reviews","reviews_per_month"]]
bos_bnb_df = bos_bnb_df.dropna()
bos_bnb_df = bos_bnb_df[bos_bnb_df["room_type"] == "Entire home/apt"]

chi_bnb_df = chi_bnb_df[["latitude","longitude","room_type","bedrooms","price","minimum_nights",
                         "availability_365","number_of_reviews","reviews_per_month"]]
chi_bnb_df = chi_bnb_df.dropna()
chi_bnb_df = chi_bnb_df[chi_bnb_df["room_type"] == "Entire home/apt"]

sd_bnb_df = sd_bnb_df[["latitude","longitude","room_type","bedrooms","price","minimum_nights",
                         "availability_365","number_of_reviews","reviews_per_month"]]
sd_bnb_df = sd_bnb_df.dropna()
sd_bnb_df = sd_bnb_df[sd_bnb_df["room_type"] == "Entire home/apt"]

sea_bnb_df = sea_bnb_df[["latitude","longitude","room_type","bedrooms","price","minimum_nights",
                         "availability_365","number_of_reviews","reviews_per_month"]]
sea_bnb_df = sea_bnb_df.dropna()
sea_bnb_df = sea_bnb_df[sea_bnb_df["room_type"] == "Entire home/apt"]

aus_bnb_df.head()
# Out:
#     latitude  longitude        room_type  bedrooms    price  minimum_nights  \
# 0  30.277500 -97.713975  Entire home/apt       2.0  $225.00               2
# 2  30.261116 -97.734483  Entire home/apt       1.0   $95.00               2
# 5  30.260273 -97.765029  Entire home/apt       1.0  $129.00               3
# 6  30.236157 -97.736823  Entire home/apt       1.0   $40.00               3
# 7  30.250150 -97.741902  Entire home/apt       2.0  $260.00               2
#
#    availability_365  number_of_reviews  reviews_per_month
# 0                52                 23               0.20
# 2               315                461               3.91
# 5               191                193               2.20
# 6               174                 45               0.42
# 7               321                 41               0.59
